# %%
# INPUT: experiment name
study_name = 'homing_cmpt'
# var_name = 'cost_comp'
# all_values = [5, 20, 50]
# ref_value = 20
cmpt_types = ['ss']
# var_dict = {'cmpt_type': ['s', 'p', 'ss', 'pp', 'sp']}  # assumes full enumeration
var_dict = {'cmpt_type': ['ss'], 'dem_mh_share': [0, 1], 'sup_mh_share': [0, 1]}  # assumes full enumeration
ref_value = [0, 0]
experiment_name = 'multi-homing'

# %%
# # Create var dict based on input
# var_dict = {'cmpt_type': cmpt_types, var_name: all_values}  # assumes full enumeration

# %%
import os
import pickle
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import itertools
path = os.getcwd()
res_path = path

# %%
# Make folder for experiment if it doesn't exist
experiment_path = os.path.join(res_path, 'plots', experiment_name)
if not os.path.exists(os.path.join(res_path, 'plots')):
    os.mkdir(os.path.join(res_path, 'plots'))
if not os.path.exists(experiment_path):
    os.mkdir(experiment_path)

# %%
# Determine scenarios - enumerating based on input
keys, values_lists = zip(*var_dict.items())
scenarios = list(itertools.product(*values_lists))
scenario_names = ['-'.join(f"{key}-{value}" for key, value in zip(keys, scenario)) for scenario in scenarios]
scenario_names = [s.replace('cmpt_type-','') for s in scenario_names]  # drop 'cmpt_type' from scn name

# %%
def open_pickle_repl(scn_dict, aggr_scn_path, pkl_name):
    with open(os.path.join(aggr_scn_path, pkl_name), 'rb') as f:
        df = pickle.load(f)
        print(df)
        for key, value in scn_dict.items():
            df[key] = value
        index_list = [key for key in scn_dict] + ['repl', 'day']
        df = df.reset_index().set_index(index_list)
    return df

# %%
scenario_names
# Out:
# ['ss-dem_mh_share-0-sup_mh_share-0',
#  'ss-dem_mh_share-0-sup_mh_share-1',
#  'ss-dem_mh_share-1-sup_mh_share-0',
#  'ss-dem_mh_share-1-sup_mh_share-1']

# %%
# Loop over scenarios, creating list of df's containing the data, and converting to single df
aggr_dem_list = []
aggr_sup_list = []
# mode_no_rs_list = []
mode_df = pd.DataFrame()
for scn_name in scenario_names:
    # Determine scenario values and save them to dict
    scn_name_split = scn_name.split('-')
    scn_dict = {}
    for i in range(1, len(scn_name_split), 2):
        variable_name = scn_name_split[i]
        print(variable_name)
        variable_value = scn_name_split[i + 1]
        print(variable_value)
        scn_dict[variable_name] = variable_value
    scn_dict['cmpt_type'] = scn_name_split[0]
    # List all folders and find those corresponding to the specific scenario
    aggr_scn_path = os.path.join(res_path, 'aggr_repl', scn_name) if (float(scn_name_split[2]) != ref_value[0] or float(scn_name_split[4]) != ref_value[1]) else os.path.join(res_path, 'aggr_repl', scn_name.split("-")[0])
    # manually adjust path to different reference experiment REMOVE LATER!
    aggr_scn_path = os.path.join(res_path, 'aggr_repl', scn_name) if (float(scn_name_split[2]) != ref_value[0] or float(scn_name_split[4]) != ref_value[1]) else os.path.join(res_path, 'aggr_repl','s')
    all_items = os.listdir(aggr_scn_path)
    aggr_dem = open_pickle_repl(scn_dict, aggr_scn_path, 'repl_dem_select.pkl')
    aggr_sup = open_pickle_repl(scn_dict, aggr_scn_path, 'repl_sup_select.pkl')

    # with open(os.path.join(aggr_scn_path, 'mode_no_rs.pkl'), 'rb') as f:
    #     mode_series = pickle.load(f)
    #     for key, value in scn_dict.items():
    #         mode_series[key] = value
    #     mode_df = mode_df.append(mode_series, ignore_index=True)
    aggr_dem_list = aggr_dem_list + [aggr_dem]
    aggr_sup_list = aggr_sup_list + [aggr_sup]
    # mode_no_rs_list = mode_no_rs_list + [df]
aggr_dem = pd.concat(aggr_dem_list)
aggr_sup = pd.concat(aggr_sup_list)
# mode_no_rs = pd.concat(mode_no_rs_list)
# Out:
# dem_mh_share
# 0
# sup_mh_share
# 0
#           informed_mh  informed_sh  registered_mh  registered_sh_0  \
# repl day
# 0    0            NaN         8401            NaN             6471
#      1            NaN        10467            NaN             7095
#      2            NaN        12364            NaN             7882
#      3            NaN        14321            NaN             8902
#      4            NaN        16156            NaN             9962
# ...               ...          ...            ...              ...
# 4    179          NaN        30906            NaN            30906
#      180          NaN        30906            NaN            30906
#      181          NaN        30906            NaN            30906
#      182          NaN        30906            NaN            30906
#      183          NaN        30906            NaN            30906
#
#           registered_sh_1  requests_mh  requests_sh_0  requests_sh_1  \
# repl day
# 0    0                NaN          NaN           2230            NaN
#      1                NaN          NaN           2232            NaN
#      2                NaN          NaN           2329            NaN
#      3                NaN          NaN           2484            NaN
#      4                NaN          NaN           2757            NaN
# ...                   ...          ...            ...            ...
# 4    179              NaN          NaN           9228            NaN
#      180              NaN          NaN           9235            NaN
#      181              NaN          NaN           9241            NaN
#      182              NaN          NaN           9240            NaN
#      183              NaN          NaN           9200            NaN
#
#           gets_offer_mh_0  gets_offer_mh_1  ...  exp_km_fare_sh_1  \
# repl day                                    ...
# 0    0                NaN              NaN  ...               NaN
#      1                NaN              NaN  ...               NaN
#      2                NaN              NaN  ...               NaN
#      3                NaN              NaN  ...               NaN
#      4                NaN              NaN  ...               NaN
# ...                   ...              ...  ...               ...
# 4    179              NaN              NaN  ...               NaN
#      180              NaN              NaN  ...               NaN
#      181              NaN              NaN  ...               NaN
#      182              NaN              NaN  ...               NaN
#      183              NaN              NaN  ...               NaN
#
#           perc_wait_mh  perc_wait_sh_0  perc_wait_sh_1  perc_detour_mh  \
# repl day
# 0    0             NaN       21.759539             NaN             NaN
#      1             NaN       44.952713             NaN             NaN
#      2             NaN       63.877590             NaN             NaN
#      3             NaN       83.457966             NaN             NaN
#      4             NaN       98.482641             NaN             NaN
# ...                ...             ...             ...             ...
# 4    179           NaN       98.472532             NaN             NaN
#      180           NaN       98.583691             NaN             NaN
#      181           NaN       98.760518             NaN             NaN
#      182           NaN       98.799689             NaN             NaN
#      183           NaN       98.920225             NaN             NaN
#
#           perc_detour_sh_0  perc_detour_sh_1  perc_km_fare_mh  \
# repl day
# 0    0       -1.612792e-08               NaN              NaN
#      1        3.114322e-08               NaN              NaN
#      2        8.700091e-08               NaN              NaN
#      3        1.004672e-07               NaN              NaN
#      4        8.499781e-08               NaN              NaN
# ...                    ...               ...              ...
# 4    179      3.427187e-07               NaN              NaN
#      180      3.589734e-07               NaN              NaN
#      181      3.474112e-07               NaN              NaN
#      182      3.451864e-07               NaN              NaN
#      183      3.217776e-07               NaN              NaN
#
#           perc_km_fare_sh_0  perc_km_fare_sh_1
# repl day
# 0    0                  1.5                NaN
#      1                  1.5                NaN
#      2                  1.5                NaN
#      3                  1.5                NaN
#      4                  1.5                NaN
# ...                     ...                ...
# 4    179                1.5                NaN
#      180                1.5                NaN
#      181                1.5                NaN
#      182                1.5                NaN
#      183                1.5                NaN
#
# [922 rows x 35 columns]
#           informed_mh  informed_sh  registered_mh  registered_sh_0  \
# repl day
# 0    0            NaN          644            NaN              234
#      1            NaN          748            NaN              234
#      2            NaN          819            NaN              229
#      3            NaN          910            NaN              230
#      4            NaN         1004            NaN              239
# ...               ...          ...            ...              ...
# 4    179          NaN         2500            NaN              579
#      180          NaN         2500            NaN              579
#      181          NaN         2500            NaN              583
#      182          NaN         2500            NaN              583
#      183          NaN         2500            NaN              583
#
#           registered_sh_1  ptcp_mh  ptcp_sh_0  ptcp_sh_1  exp_inc_mh  \
# repl day
# 0    0                NaN      NaN        144        NaN         NaN
#      1                NaN      NaN        134        NaN         NaN
#      2                NaN      NaN        129        NaN         NaN
#      3                NaN      NaN        123        NaN         NaN
#      4                NaN      NaN        130        NaN         NaN
# ...                   ...      ...        ...        ...         ...
# 4    179              NaN      NaN        456        NaN         NaN
#      180              NaN      NaN        466        NaN         NaN
#      181              NaN      NaN        467        NaN         NaN
#      182              NaN      NaN        470        NaN         NaN
#      183              NaN      NaN        469        NaN         NaN
#
#           exp_inc_sh_0  exp_inc_sh_1  perc_inc_mh  perc_inc_sh_0  \
# repl day
# 0    0       87.878872           NaN          NaN     161.943664
#      1       95.047239           NaN          NaN     143.385035
#      2      103.120252           NaN          NaN     133.856145
#      3      115.706159           NaN          NaN     129.656082
#      4      122.038962           NaN          NaN     128.360722
# ...                ...           ...          ...            ...
# 4    179    117.575789           NaN          NaN     115.032718
#      180    115.371540           NaN          NaN     115.043946
#      181    114.565905           NaN          NaN     115.006431
#      182    114.069064           NaN          NaN     114.917903
#      183    114.171924           NaN          NaN     114.846914
#
#           perc_inc_sh_1  new_regist_sh_0  new_deregist_sh_0  new_regist_sh_1  \
# repl day
# 0    0              NaN                0                  0                0
#      1              NaN               11                 11                0
#      2              NaN               12                 17                0
#      3              NaN               23                 22                0
#      4              NaN               23                 14                0
# ...                 ...              ...                ...              ...
# 4    179            NaN               12                  0                0
#      180            NaN                3                  3                0
#      181            NaN                5                  1                0
#      182            NaN                3                  3                0
#      183            NaN                3                  3                0
#
#           new_deregist_sh_1  new_regist_mh  new_deregist_mh
# repl day
# 0    0                    0              0                0
#      1                    0              0                0
#      2                    0              0                0
#      3                    0              0                0
#      4                    0              0                0
# ...                     ...            ...              ...
# 4    179                  0              0                0
#      180                  0              0                0
#      181                  0              0                0
#      182                  0              0                0
#      183                  0              0                0
#
# [922 rows x 20 columns]
# dem_mh_share
# 0
# sup_mh_share
# 1
#           informed_mh  informed_sh  registered_mh  registered_sh_0  \
# repl day
# 0    0            NaN         8361            NaN             3190
#      1            NaN        10372            NaN             3475
#      2            NaN        12244            NaN             3904
#      3            NaN        14099            NaN             4461
#      4            NaN        15791            NaN             5030
# ...               ...          ...            ...              ...
# 2    191          NaN        30953            NaN            15575
#      192          NaN        30953            NaN            15571
#      193          NaN        30953            NaN            15592
#      194          NaN        30953            NaN            15600
#      195          NaN        30953            NaN            15696
#
#           registered_sh_1  requests_mh  requests_sh_0  requests_sh_1  \
# repl day
# 0    0               3251          NaN           1090           1149
#      1               3515          NaN           1123           1151
#      2               3823          NaN           1099           1185
#      3               4211          NaN           1225           1222
#      4               4718          NaN           1324           1268
# ...                   ...          ...            ...            ...
# 2    191            15377          NaN           4752           4688
#      192            15381          NaN           4794           4649
#      193            15360          NaN           4835           4718
#      194            15352          NaN           4780           4682
#      195            15256          NaN           4747           4701
#
#           requests_sh_largest  gets_offer_mh_0  ...  perc_wait_sh_0  \
# repl day                                        ...
# 0    0                   1149              NaN  ...       43.231465
#      1                   1151              NaN  ...       76.371652
#      2                   1185              NaN  ...       95.759458
#      3                   1225              NaN  ...      119.612242
#      4                   1324              NaN  ...      136.862250
# ...                       ...              ...  ...             ...
# 2    191                 4752              NaN  ...       96.919996
#      192                 4794              NaN  ...       96.690337
#      193                 4835              NaN  ...       96.667048
#      194                 4780              NaN  ...       96.728625
#      195                 4747              NaN  ...       96.469289
#
#           perc_wait_sh_1  perc_wait_sh_largest  perc_wait_sh_smallest  \
# repl day
# 0    0         43.697209             43.697209              43.231465
#      1         77.469231             77.469231              76.371652
#      2         99.280462             99.280462              95.759458
#      3        124.809526            119.612242             124.809526
#      4        141.518060            136.862250             141.518060
# ...                  ...                   ...                    ...
# 2    191       97.078054             96.919996              97.078054
#      192       96.899474             96.690337              96.899474
#      193       97.252256             96.667048              97.252256
#      194       97.270497             96.728625              97.270497
#      195       97.312967             96.469289              97.312967
#
#           perc_detour_mh  perc_detour_sh_0  perc_detour_sh_1  perc_km_fare_mh  \
# repl day
# 0    0               NaN      1.104434e-07     -5.798903e-09              NaN
#      1               NaN      1.576994e-07     -7.769275e-08              NaN
#      2               NaN      1.847485e-07     -3.420210e-05              NaN
#      3               NaN      1.973428e-07     -2.264052e-05              NaN
#      4               NaN      1.827163e-07     -1.524219e-05              NaN
# ...                  ...               ...               ...              ...
# 2    191             NaN      2.315695e-08      1.806973e-07              NaN
#      192             NaN      1.265412e-08      1.706139e-07              NaN
#      193             NaN      1.788089e-08      1.593795e-07              NaN
#      194             NaN      1.342967e-08      1.611105e-07              NaN
#      195             NaN     -1.706468e-09      1.522309e-07              NaN
#
#           perc_km_fare_sh_0  perc_km_fare_sh_1
# repl day
# 0    0                  1.5           1.500000
#      1                  1.5           1.500000
#      2                  1.5           1.499949
#      3                  1.5           1.499966
#      4                  1.5           1.499977
# ...                     ...                ...
# 2    191                1.5           1.500000
#      192                1.5           1.500000
#      193                1.5           1.500000
#      194                1.5           1.500000
#      195                1.5           1.500000
#
# [570 rows x 44 columns]
#           informed_mh  informed_sh  registered_mh  registered_sh_0  \
# repl day
# 0    0            645          NaN            233              NaN
#      1            749          NaN            222              NaN
#      2            843          NaN            217              NaN
#      3            914          NaN            219              NaN
#      4            976          NaN            230              NaN
# ...               ...          ...            ...              ...
# 2    191         2500          NaN            598              NaN
#      192         2500          NaN            597              NaN
#      193         2500          NaN            598              NaN
#      194         2500          NaN            600              NaN
#      195         2500          NaN            600              NaN
#
#           registered_sh_1  ptcp_mh  ptcp_sh_0  ptcp_sh_1  ptcp_sh_largest  \
# repl day
# 0    0                NaN      144        NaN        NaN              NaN
#      1                NaN      135        NaN        NaN              NaN
#      2                NaN      131        NaN        NaN              NaN
#      3                NaN      120        NaN        NaN              NaN
#      4                NaN      122        NaN        NaN              NaN
# ...                   ...      ...        ...        ...              ...
# 2    191              NaN      481        NaN        NaN              NaN
#      192              NaN      481        NaN        NaN              NaN
#      193              NaN      478        NaN        NaN              NaN
#      194              NaN      481        NaN        NaN              NaN
#      195              NaN      485        NaN        NaN              NaN
#
#           exp_inc_mh  ...  perc_inc_sh_0  perc_inc_sh_1  perc_inc_sh_largest  \
# repl day              ...
# 0    0     88.030955  ...            NaN            NaN                  NaN
#      1     95.851000  ...            NaN            NaN                  NaN
#      2     98.527576  ...            NaN            NaN                  NaN
#      3    115.386042  ...            NaN            NaN                  NaN
#      4    121.957439  ...            NaN            NaN                  NaN
# ...              ...  ...            ...            ...                  ...
# 2    191  114.815473  ...            NaN            NaN                  NaN
#      192  114.596107  ...            NaN            NaN                  NaN
#      193  116.841229  ...            NaN            NaN                  NaN
#      194  114.661424  ...            NaN            NaN                  NaN
#      195  113.803665  ...            NaN            NaN                  NaN
#
#           perc_inc_sh_smallest  new_regist_sh_0  new_deregist_sh_0  \
# repl day
# 0    0                     NaN                0                  0
#      1                     NaN                0                  0
#      2                     NaN                0                  0
#      3                     NaN                0                  0
#      4                     NaN                0                  0
# ...                        ...              ...                ...
# 2    191                   NaN                0                  0
#      192                   NaN                0                  0
#      193                   NaN                0                  0
#      194                   NaN                0                  0
#      195                   NaN                0                  0
#
#           new_regist_sh_1  new_deregist_sh_1  new_regist_mh  new_deregist_mh
# repl day
# 0    0                  0                  0              0                0
#      1                  0                  0             12               23
#      2                  0                  0             10               15
#      3                  0                  0             12               10
#      4                  0                  0             20                9
# ...                   ...                ...            ...              ...
# 2    191                0                  0              7                5
#      192                0                  0              3                4
#      193                0                  0              7                6
#      194                0                  0              7                5
#      195                0                  0              5                5
#
# [570 rows x 25 columns]
# dem_mh_share
# 1
# sup_mh_share
# 0
#           informed_mh  informed_sh  registered_mh  registered_sh_0  \
# repl day
# 0    0           8336          NaN           6419              NaN
#      1          10418          NaN           7031              NaN
#      2          12392          NaN           7854              NaN
#      3          14292          NaN           8859              NaN
#      4          16012          NaN           9922              NaN
# ...               ...          ...            ...              ...
# 2    173        30953          NaN          30952              NaN
#      174        30953          NaN          30952              NaN
#      175        30953          NaN          30952              NaN
#      176        30953          NaN          30952              NaN
#      177        30953          NaN          30951              NaN
#
#           registered_sh_1  requests_mh  requests_sh_0  requests_sh_1  \
# repl day
# 0    0                NaN         2195            NaN            NaN
#      1                NaN         2234            NaN            NaN
#      2                NaN         2333            NaN            NaN
#      3                NaN         2460            NaN            NaN
#      4                NaN         2730            NaN            NaN
# ...                   ...          ...            ...            ...
# 2    173              NaN         9587            NaN            NaN
#      174              NaN         9597            NaN            NaN
#      175              NaN         9605            NaN            NaN
#      176              NaN         9640            NaN            NaN
#      177              NaN         9563            NaN            NaN
#
#           requests_sh_largest  gets_offer_mh_0  ...  perc_wait_sh_0  \
# repl day                                        ...
# 0    0                    NaN             2191  ...             NaN
#      1                    NaN             2228  ...             NaN
#      2                    NaN             2331  ...             NaN
#      3                    NaN             2451  ...             NaN
#      4                    NaN             2727  ...             NaN
# ...                       ...              ...  ...             ...
# 2    173                  NaN             9584  ...             NaN
#      174                  NaN             9592  ...             NaN
#      175                  NaN             9593  ...             NaN
#      176                  NaN             9627  ...             NaN
#      177                  NaN             9560  ...             NaN
#
#           perc_wait_sh_1  perc_wait_sh_largest  perc_wait_sh_smallest  \
# repl day
# 0    0               NaN                   NaN                    NaN
#      1               NaN                   NaN                    NaN
#      2               NaN                   NaN                    NaN
#      3               NaN                   NaN                    NaN
#      4               NaN                   NaN                    NaN
# ...                  ...                   ...                    ...
# 2    173             NaN                   NaN                    NaN
#      174             NaN                   NaN                    NaN
#      175             NaN                   NaN                    NaN
#      176             NaN                   NaN                    NaN
#      177             NaN                   NaN                    NaN
#
#           perc_detour_mh  perc_detour_sh_0  perc_detour_sh_1  perc_km_fare_mh  \
# repl day
# 0    0      6.365920e-08               NaN               NaN              1.5
#      1      9.908883e-08               NaN               NaN              1.5
#      2      1.080123e-07               NaN               NaN              1.5
#      3      7.257100e-08               NaN               NaN              1.5
#      4      9.456111e-08               NaN               NaN              1.5
# ...                  ...               ...               ...              ...
# 2    173    1.856771e-07               NaN               NaN              1.5
#      174    1.964854e-07               NaN               NaN              1.5
#      175    1.859613e-07               NaN               NaN              1.5
#      176    1.850090e-07               NaN               NaN              1.5
#      177    1.629082e-07               NaN               NaN              1.5
#
#           perc_km_fare_sh_0  perc_km_fare_sh_1
# repl day
# 0    0                  NaN                NaN
#      1                  NaN                NaN
#      2                  NaN                NaN
#      3                  NaN                NaN
#      4                  NaN                NaN
# ...                     ...                ...
# 2    173                NaN                NaN
#      174                NaN                NaN
#      175                NaN                NaN
#      176                NaN                NaN
#      177                NaN                NaN
#
# [585 rows x 42 columns]
#           informed_mh  informed_sh  registered_mh  registered_sh_0  \
# repl day
# 0    0            NaN          586            NaN              108
#      1            NaN          693            NaN              111
#      2            NaN          776            NaN              116
#      3            NaN          872            NaN              108
#      4            NaN          933            NaN              118
# ...               ...          ...            ...              ...
# 2    173          NaN         2500            NaN              306
#      174          NaN         2500            NaN              305
#      175          NaN         2500            NaN              312
#      176          NaN         2500            NaN              321
#      177          NaN         2500            NaN              304
#
#           registered_sh_1  ptcp_mh  ptcp_sh_0  ptcp_sh_1  ptcp_sh_largest  \
# repl day
# 0    0                106      NaN         65         68               68
#      1                102      NaN         61         57               61
#      2                103      NaN         68         53               68
#      3                117      NaN         74         51               74
#      4                105      NaN         67         68               68
# ...                   ...      ...        ...        ...              ...
# 2    173              316      NaN        238        250              250
#      174              314      NaN        239        251              251
#      175              305      NaN        236        252              252
#      176              300      NaN        241        246              246
#      177              316      NaN        250        242              250
#
#           exp_inc_mh  ...  perc_inc_sh_0  perc_inc_sh_1  perc_inc_sh_largest  \
# repl day              ...
# 0    0           NaN  ...     145.551356     147.973405           147.973405
#      1           NaN  ...     131.245130     132.513897           131.245130
#      2           NaN  ...     124.426393     125.309034           124.426393
#      3           NaN  ...     120.135283     121.995955           120.135283
#      4           NaN  ...     119.404400     120.234091           120.234091
# ...              ...  ...            ...            ...                  ...
# 2    173         NaN  ...     114.479855     114.162341           114.162341
#      174         NaN  ...     114.487213     114.038488           114.038488
#      175         NaN  ...     114.619697     113.902016           113.902016
#      176         NaN  ...     114.713425     113.886119           113.886119
#      177         NaN  ...     114.441268     113.972812           114.441268
#
#           perc_inc_sh_smallest  new_regist_sh_0  new_deregist_sh_0  \
# repl day
# 0    0              145.551356                0                  0
#      1              132.513897               10                  7
#      2              125.309034               14                  9
#      3              121.995955                0                  8
#      4              119.404400               12                  2
# ...                        ...              ...                ...
# 2    173            114.479855               15                 15
#      174            114.487213                9                 10
#      175            114.619697               19                 12
#      176            114.713425               18                  9
#      177            113.972812                6                 23
#
#           new_regist_sh_1  new_deregist_sh_1  new_regist_mh  new_deregist_mh
# repl day
# 0    0                  0                  0              0                0
#      1                  4                  8              0                0
#      2                  5                  4              0                0
#      3                 24                 10              0                0
#      4                  3                 15              0                0
# ...                   ...                ...            ...              ...
# 2    173               14                 13              0                0
#      174               11                 13              0                0
#      175               10                 19              0                0
#      176               10                 15              0                0
#      177               23                  7              0                0
#
# [585 rows x 25 columns]
# dem_mh_share
# 1
# sup_mh_share
# 1
#           informed_mh  informed_sh  registered_mh  registered_sh_0  \
# repl day
# 0    0           8393          NaN           6491              NaN
#      1          10558          NaN           7069              NaN
#      2          12435          NaN           7853              NaN
#      3          14348          NaN           8832              NaN
#      4          16058          NaN           9894              NaN
# ...               ...          ...            ...              ...
# 2    178        30953          NaN          30952              NaN
#      179        30953          NaN          30952              NaN
#      180        30953          NaN          30952              NaN
#      181        30953          NaN          30952              NaN
#      182        30953          NaN          30952              NaN
#
#           registered_sh_1  requests_mh  requests_sh_0  requests_sh_1  \
# repl day
# 0    0                NaN         2226            NaN            NaN
#      1                NaN         2281            NaN            NaN
#      2                NaN         2328            NaN            NaN
#      3                NaN         2475            NaN            NaN
#      4                NaN         2687            NaN            NaN
# ...                   ...          ...            ...            ...
# 2    178              NaN         9662            NaN            NaN
#      179              NaN         9649            NaN            NaN
#      180              NaN         9694            NaN            NaN
#      181              NaN         9699            NaN            NaN
#      182              NaN         9626            NaN            NaN
#
#           requests_sh_largest  gets_offer_mh_0  ...  perc_wait_sh_0  \
# repl day                                        ...
# 0    0                    NaN             2224  ...             NaN
#      1                    NaN             2277  ...             NaN
#      2                    NaN             2327  ...             NaN
#      3                    NaN             2473  ...             NaN
#      4                    NaN             2674  ...             NaN
# ...                       ...              ...  ...             ...
# 2    178                  NaN             9660  ...             NaN
#      179                  NaN             9648  ...             NaN
#      180                  NaN             9685  ...             NaN
#      181                  NaN             9697  ...             NaN
#      182                  NaN             9626  ...             NaN
#
#           perc_wait_sh_1  perc_wait_sh_largest  perc_wait_sh_smallest  \
# repl day
# 0    0               NaN                   NaN                    NaN
#      1               NaN                   NaN                    NaN
#      2               NaN                   NaN                    NaN
#      3               NaN                   NaN                    NaN
#      4               NaN                   NaN                    NaN
# ...                  ...                   ...                    ...
# 2    178             NaN                   NaN                    NaN
#      179             NaN                   NaN                    NaN
#      180             NaN                   NaN                    NaN
#      181             NaN                   NaN                    NaN
#      182             NaN                   NaN                    NaN
#
#           perc_detour_mh  perc_detour_sh_0  perc_detour_sh_1  perc_km_fare_mh  \
# repl day
# 0    0      7.340539e-08               NaN               NaN              1.5
#      1      1.240150e-07               NaN               NaN              1.5
#      2      1.396252e-07               NaN               NaN              1.5
#      3      1.598465e-07               NaN               NaN              1.5
#      4      1.736676e-07               NaN               NaN              1.5
# ...                  ...               ...               ...              ...
# 2    178    9.032972e-08               NaN               NaN              1.5
#      179    1.046656e-07               NaN               NaN              1.5
#      180    1.131720e-07               NaN               NaN              1.5
#      181    1.166922e-07               NaN               NaN              1.5
#      182    9.019353e-08               NaN               NaN              1.5
#
#           perc_km_fare_sh_0  perc_km_fare_sh_1
# repl day
# 0    0                  NaN                NaN
#      1                  NaN                NaN
#      2                  NaN                NaN
#      3                  NaN                NaN
#      4                  NaN                NaN
# ...                     ...                ...
# 2    178                NaN                NaN
#      179                NaN                NaN
#      180                NaN                NaN
#      181                NaN                NaN
#      182                NaN                NaN
#
# [572 rows x 44 columns]
#           informed_mh  informed_sh  registered_mh  registered_sh_0  \
# repl day
# 0    0            599          NaN            221              NaN
#      1            698          NaN            217              NaN
#      2            793          NaN            214              NaN
#      3            875          NaN            213              NaN
#      4            939          NaN            216              NaN
# ...               ...          ...            ...              ...
# 2    178         2500          NaN            618              NaN
#      179         2500          NaN            622              NaN
#      180         2500          NaN            625              NaN
#      181         2500          NaN            626              NaN
#      182         2500          NaN            627              NaN
#
#           registered_sh_1  ptcp_mh  ptcp_sh_0  ptcp_sh_1  ptcp_sh_largest  \
# repl day
# 0    0                NaN      133        NaN        NaN              NaN
#      1                NaN      124        NaN        NaN              NaN
#      2                NaN      119        NaN        NaN              NaN
#      3                NaN      122        NaN        NaN              NaN
#      4                NaN      121        NaN        NaN              NaN
# ...                   ...      ...        ...        ...              ...
# 2    178              NaN      488        NaN        NaN              NaN
#      179              NaN      488        NaN        NaN              NaN
#      180              NaN      489        NaN        NaN              NaN
#      181              NaN      493        NaN        NaN              NaN
#      182              NaN      493        NaN        NaN              NaN
#
#           exp_inc_mh  ...  perc_inc_sh_0  perc_inc_sh_1  perc_inc_sh_largest  \
# repl day              ...
# 0    0     94.652914  ...            NaN            NaN                  NaN
#      1    104.013004  ...            NaN            NaN                  NaN
#      2    110.500546  ...            NaN            NaN                  NaN
#      3    115.695676  ...            NaN            NaN                  NaN
#      4    127.261302  ...            NaN            NaN                  NaN
# ...              ...  ...            ...            ...                  ...
# 2    178  115.649175  ...            NaN            NaN                  NaN
#      179  115.595809  ...            NaN            NaN                  NaN
#      180  115.629422  ...            NaN            NaN                  NaN
#      181  114.892150  ...            NaN            NaN                  NaN
#      182  114.013448  ...            NaN            NaN                  NaN
#
#           perc_inc_sh_smallest  new_regist_sh_0  new_deregist_sh_0  \
# repl day
# 0    0                     NaN                0                  0
#      1                     NaN                0                  0
#      2                     NaN                0                  0
#      3                     NaN                0                  0
#      4                     NaN                0                  0
# ...                        ...              ...                ...
# 2    178                   NaN                0                  0
#      179                   NaN                0                  0
#      180                   NaN                0                  0
#      181                   NaN                0                  0
#      182                   NaN                0                  0
#
#           new_regist_sh_1  new_deregist_sh_1  new_regist_mh  new_deregist_mh
# repl day
# 0    0                  0                  0              0                0
#      1                  0                  0              9               13
#      2                  0                  0             16               19
#      3                  0                  0              9               10
#      4                  0                  0             22               19
# ...                   ...                ...            ...              ...
# 2    178                0                  0              1                3
#      179                0                  0              5                1
#      180                0                  0              9                6
#      181                0                  0              5                4
#      182                0                  0              3                2
#
# [572 rows x 25 columns]

# %%
# # aggr_dem.columns = aggr_dem.columns.droplevel(0)
# # aggr_dem.columns.name = None               #remove categories
# aggr_dem = aggr_dem.reset_index().set_index(['cmpt_type','repl','day'])   
# aggr_dem
# # aggr_dem.reset_index()
# # aggr_dem.requests_0

# %%
aggr_dem.keys()
# Out:
# Index(['informed_mh', 'informed_sh', 'registered_mh', 'registered_sh_0',
#        'registered_sh_1', 'requests_mh', 'requests_sh_0', 'requests_sh_1',
#        'gets_offer_mh_0', 'gets_offer_mh_1', 'gets_offer_sh_0',
#        'gets_offer_sh_1', 'accepts_offer_mh_0', 'accepts_offer_mh_1',
#        'exp_wait_mh', 'exp_wait_sh_0', 'exp_wait_sh_1', 'exp_corr_wait_mh',
#        'exp_corr_wait_sh_0', 'exp_corr_wait_sh_1', 'exp_detour_mh',
#        'exp_detour_sh_0', 'exp_detour_sh_1', 'exp_km_fare_mh',
#        'exp_km_fare_sh_0', 'exp_km_fare_sh_1', 'perc_wait_mh',
#        'perc_wait_sh_0', 'perc_wait_sh_1', 'perc_detour_mh',
#        'perc_detour_sh_0', 'perc_detour_sh_1', 'perc_km_fare_mh',
#        'perc_km_fare_sh_0', 'perc_km_fare_sh_1', 'requests_sh_largest',
#        'gets_offer_mh_largest', 'accepts_offer_mh_largest',
#        'exp_wait_sh_largest', 'exp_wait_sh_smallest',
#        'exp_corr_wait_sh_largest', 'exp_corr_wait_sh_smallest',
#        'perc_wait_sh_largest', 'perc_wait_sh_smallest'],
#       dtype='object')

# %%
# Add scenario label
non_day_level = [level for level in aggr_dem.index.names if level != 'day' and level !='repl'] # Find the scenario indices
if len(non_day_level) == 1:
    aggr_dem['label'] = aggr_dem.index.get_level_values(non_day_level[0])
    aggr_sup['label'] = aggr_sup.index.get_level_values(non_day_level[0])
else:
    aggr_dem['label'] = aggr_dem.index.to_frame(index=False)[non_day_level].astype(str).apply(lambda row: '_'.join(row))
    aggr_sup['label'] = aggr_sup.index.to_frame(index=False)[non_day_level].astype(str).apply(lambda row: '_'.join(row))

# %%
non_day_level
# Out:
# ['dem_mh_share', 'sup_mh_share', 'cmpt_type']

# %%
aggr_sup.keys()
# result = aggr_sup.groupby(level='day').sum().xs(('sp', 0), level=['cmpt_type', 'repl'])
aggr_sup.exp_inc_sh_largest
aggr_sup.exp_inc_mh
# Out:
# dem_mh_share  sup_mh_share  cmpt_type  repl  day
# 0             0             ss         0     0             NaN
#                                              1             NaN
#                                              2             NaN
#                                              3             NaN
#                                              4             NaN
#                                                        ...
# 1             1             ss         2     178    115.649175
#                                              179    115.595809
#                                              180    115.629422
#                                              181    114.892150
#                                              182    114.013448
# Name: exp_inc_mh, Length: 2649, dtype: float64

# %%
aggr_dem['req'] = aggr_dem['gets_offer_sh_0'].fillna(0) + aggr_dem['gets_offer_sh_1'].fillna(0) + aggr_dem['requests_mh'].fillna(0)
aggr_sup['ptcp'] = aggr_sup['ptcp_sh_0'].fillna(0) + aggr_sup['ptcp_sh_1'].fillna(0) + aggr_sup['ptcp_mh'].fillna(0)

# Specify the columns to plot
columns_to_plot_dem = ['req', 'exp_corr_wait_sh_largest' ] #'exp_corr_wait_sh_0'
columns_to_plot_sup = ['ptcp', 'exp_inc_sh_largest']
column_labels = ['Demand Column 1', 'Demand Column 2', 'Supply Column 1', 'Supply Column 2']
colors = ['r', 'g', 'b', 'm', 'y']

# Extract unique combinations of 'dem_mh_share', 'sup_mh_share', and 'cmpt_type'
unique_combinations_dem = aggr_dem.index.droplevel(['repl', 'day']).unique()
unique_combinations_sup = aggr_sup.index.droplevel(['repl', 'day']).unique()

# Create subplots
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
axes = axes.flatten()

# Plot data from aggr_dem
for j, column in enumerate(columns_to_plot_dem):
    ax = axes[j]  # Select the subplot
    for i, (dem_mh_share, sup_mh_share, cmpt_type) in enumerate(unique_combinations_dem):
        column_to_plot = column
        if (dem_mh_share == '1' and sup_mh_share == '1') or (dem_mh_share == '0' and sup_mh_share == '0'):
            if dem_mh_share == '0' and sup_mh_share == '0' and column == 'exp_corr_wait_sh_largest':
                column_to_plot = 'exp_corr_wait_sh_0'
            elif dem_mh_share == '1' and sup_mh_share == '1' and column == 'exp_corr_wait_sh_largest':
                column_to_plot = 'exp_corr_wait_mh'
            subset = aggr_dem.xs((dem_mh_share, sup_mh_share, cmpt_type), level=['dem_mh_share', 'sup_mh_share', 'cmpt_type'])
            for repl in subset.index.get_level_values('repl').unique():
                repl_subset = subset.xs(repl, level='repl')
                day_values = repl_subset.index.get_level_values('day')
                values = repl_subset[column_to_plot].values
                
                # Plot the data directly, including NaNs
                ax.plot(day_values, values, label=f'{dem_mh_share, sup_mh_share}, repl {repl}', color=colors[i % len(colors)], alpha=0.6)
        
        ax.set_xlabel('Day')
        ax.set_ylabel('Value')
        ax.set_title(f'{column_labels[j]}')
        ax.legend()

# Plot data from aggr_sup
for j, column in enumerate(columns_to_plot_sup):
    ax = axes[j + len(columns_to_plot_dem)]  # Select the subplot
    for i, (dem_mh_share, sup_mh_share, cmpt_type) in enumerate(unique_combinations_sup):
        column_to_plot = column
        if (dem_mh_share == '1' and sup_mh_share == '1') or (dem_mh_share == '0' and sup_mh_share == '0'):
            if dem_mh_share == '0' and sup_mh_share == '0' and column == 'exp_inc_sh_largest':
                column_to_plot = 'exp_inc_sh_0'
            if dem_mh_share == '1' and sup_mh_share == '1' and column == 'exp_inc_sh_largest':
                column_to_plot = 'exp_inc_mh'
            subset = aggr_sup.xs((dem_mh_share, sup_mh_share, cmpt_type), level=['dem_mh_share', 'sup_mh_share', 'cmpt_type'])
            for repl in subset.index.get_level_values('repl').unique():
                repl_subset = subset.xs(repl, level='repl')
                day_values = repl_subset.index.get_level_values('day')
                values = repl_subset[column_to_plot].values
                
                # Plot the data directly
                ax.plot(day_values, values, label=f'{dem_mh_share, sup_mh_share}, repl {repl}', color=colors[i % len(colors)], alpha=0.6)
        
        ax.set_xlabel('Day')
        ax.set_ylabel('Value')
        ax.set_title(f'{column_labels[j + len(columns_to_plot_dem)]}')
        ax.legend()

plt.tight_layout()
plt.show()

# %%
aggr_dem.req
# Out:
# dem_mh_share  sup_mh_share  cmpt_type  repl  day
# 0             0             ss         0     0      2227.0
#                                              1      2229.0
#                                              2      2327.0
#                                              3      2479.0
#                                              4      2753.0
#                                                      ...
# 1             1             ss         2     178    9662.0
#                                              179    9649.0
#                                              180    9694.0
#                                              181    9699.0
#                                              182    9626.0
# Name: req, Length: 2649, dtype: float64

# %%
# Get unique 'a' values
# unique_cmpt_values = aggr_sup.index.get_level_values('cmpt_type').unique()
unique_cmpt_values = aggr_sup.index.get_level_values('cmpt_type').unique()

# Create subplots
fig, axes = plt.subplots(2,2, figsize=(12, 8))

indicators = ['ptcp_sh', 'exp_inc_sh']
indicator_labels = ['Fleet size', 'Income']
colors = ['r','k','g','b','y']

for i, cmpt_type in enumerate(unique_cmpt_values):
    for j, indicator in enumerate(indicators):
        for plf in [0,1]:
            ax = axes[j, plf]
            for repl in aggr_sup.xs((cmpt_type,cmpt_types[0])).index.get_level_values('repl').unique():
                subset = aggr_sup.loc[(cmpt_type, cmpt_types[0], repl), indicator + '_{}'.format(plf)]
                day_values = subset.index.get_level_values('day')
                values = subset.values
                non_nan_indices = ~np.isnan(values)
                if repl == aggr_sup.xs((cmpt_type, cmpt_types[0])).index.get_level_values('repl').unique()[-1]:
                    ax.plot(day_values[non_nan_indices], values[non_nan_indices], label='{}'.format(cmpt_type),color=colors[i], alpha=0.2)
                else:
                    ax.plot(day_values[non_nan_indices], values[non_nan_indices],color=colors[i], alpha=0.2)
            # ax.set_title(f'a={a_value} - {column}')
            ax.set_xlabel('Day')
            ax.set_ylabel('Value')
            ax.set_title('{} platform {}'.format(indicator_labels[j],plf))
            ax.legend()

axes[0,0].set_ylim(0,500)
axes[0,1].set_ylim(0,500)
axes[1,0].set_ylim(50,140)
axes[1,1].set_ylim(50,140)

plt.tight_layout()
plt.savefig(os.path.join(experiment_path,'Evo-supply.png'), facecolor='w')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_59580\1463004133.py in <module>
#      14         for plf in [0,1]:
#      15             ax = axes[j, plf]
# ---> 16             for repl in aggr_sup.xs((cmpt_type,cmpt_types[0])).index.get_level_values('repl').unique():
#      17                 subset = aggr_sup.loc[(cmpt_type, cmpt_types[0], repl), indicator + '_{}'.format(plf)]
#      18                 day_values = subset.index.get_level_values('day')
#
# c:\Users\ge27fus\.conda\envs\fleetmaas_eval\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3732             try:
#    3733                 loc, new_index = index._get_loc_level(
# -> 3734                     key, level=0, drop_level=drop_level
#    3735                 )
#    3736             except TypeError as e:
#
# c:\Users\ge27fus\.conda\envs\fleetmaas_eval\lib\site-packages\pandas\core\indexes\multi.py in _get_loc_level(self, key, level, drop_level)
#    3038                         raise KeyError(key) from e
#    3039                 else:
# -> 3040                     return partial_selection(key)
#    3041             else:
#    3042                 indexer = None
#
# c:\Users\ge27fus\.conda\envs\fleetmaas_eval\lib\site-packages\pandas\core\indexes\multi.py in partial_selection(key, indexer)
#    3025                 def partial_selection(key, indexer=None):
#    3026                     if indexer is None:
# -> 3027                         indexer = self.get_loc(key)
#    3028                     ilevels = [
#    3029                         i for i in range(len(key)) if key[i] != slice(None, None)
#
# c:\Users\ge27fus\.conda\envs\fleetmaas_eval\lib\site-packages\pandas\core\indexes\multi.py in get_loc(self, key, method)
#    2897
#    2898         if start == stop:
# -> 2899             raise KeyError(key)
#    2900
#    2901         if not follow_key:
#
# KeyError: ('ss', 'ss')

# %%
unique_cmpt_values
# Out:
# Index(['ss'], dtype='object', name='cmpt_type')

# %%
# Get unique 'a' values
# unique_cmpt_values = aggr_dem.index.get_level_values('cmpt_type').unique()
unique_cmpt_values = aggr_dem.index.get_level_values(var_dict[0]).unique()

# Create subplots
fig, axes = plt.subplots(4,2, figsize=(12, 12))

aggr_dem['service_rate_sh_0'] = aggr_dem['gets_offer_sh_0'] / aggr_dem['requests_sh_0']
aggr_dem['service_rate_sh_1'] = aggr_dem['gets_offer_sh_1'] / aggr_dem['requests_sh_1']

indicators = ['requests_sh', 'service_rate_sh', 'exp_wait_sh', 'exp_detour_sh']
indicator_labels = ['Demand', 'Service rate', 'Waiting time', 'Pooling detour']
colors = ['r','k','g','b','y']

for i, cmpt_type in enumerate(unique_cmpt_values):
    for j, indicator in enumerate(indicators):
        for plf in [0,1]:
            ax = axes[j, plf]
            for repl in aggr_dem.xs((cmpt_type, cmpt_types[0])).index.get_level_values('repl').unique():
                subset = aggr_dem.loc[(cmpt_type, cmpt_types[0], repl), indicator + '_{}'.format(plf)]
                day_values = subset.index.get_level_values('day')
                values = subset.values
                non_nan_indices = ~np.isnan(values)
                if repl == aggr_dem.xs((cmpt_type, cmpt_types[0])).index.get_level_values('repl').unique()[-1]:
                    ax.plot(day_values[non_nan_indices], values[non_nan_indices], label='{}'.format(cmpt_type),color=colors[i], alpha=0.2)
                else:
                    ax.plot(day_values[non_nan_indices], values[non_nan_indices],color=colors[i], alpha=0.2)
            # ax.set_title(f'a={a_value} - {column}')
            ax.set_xlabel('Day')
            ax.set_ylabel('Value')
            ax.set_title('{} platform {}'.format(indicator_labels[j],plf))
            ax.legend()

axes[0,0].set_ylim(0,10000)
axes[0,1].set_ylim(0,10000)
axes[1,0].set_ylim(0.6,1)
axes[1,1].set_ylim(0.6,1)
axes[2,0].set_ylim(0,400)
axes[2,1].set_ylim(0,400)
axes[3,0].set_ylim(0,0.2)
axes[3,1].set_ylim(0,0.2)

plt.tight_layout()
plt.savefig(os.path.join(experiment_path,'Evo-demand.png'), facecolor='w')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_59580\4171315403.py in <module>
#       1 # Get unique 'a' values
#       2 # unique_cmpt_values = aggr_dem.index.get_level_values('cmpt_type').unique()
# ----> 3 unique_cmpt_values = aggr_dem.index.get_level_values(var_dict[0]).unique()
#       4
#       5 # Create subplots
#
# KeyError: 0

# %%
aggr_dem.xs(('0',cmpt_types[0],2)).requests_sh_0.plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\ge27fus\.conda\envs\fleetmaas\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '0'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-6a3a9715c348> in <module>
# ----> 1 aggr_dem.xs(('0',cmpt_types[0],2)).requests_sh_0.plot()
#
# c:\Users\ge27fus\.conda\envs\fleetmaas\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3729             try:
#    3730                 loc, new_index = index._get_loc_level(
# -> 3731                     key, level=0, drop_level=drop_level
#    3732                 )
#    3733             except TypeError as e:
#
# c:\Users\ge27fus\.conda\envs\fleetmaas\lib\site-packages\pandas\core\indexes\multi.py in _get_loc_level(self, key, level, drop_level)
#    3036                         raise KeyError(key) from e
#    3037                 else:
# -> 3038                     return partial_selection(key)
#    3039             else:
#    3040                 indexer = None
#
# c:\Users\ge27fus\.conda\envs\fleetmaas\lib\site-packages\pandas\core\indexes\multi.py in partial_selection(key, indexer)
#    3023                 def partial_selection(key, indexer=None):
#    3024                     if indexer is None:
# -> 3025                         indexer = self.get_loc(key)
#    3026                     ilevels = [
#    3027                         i for i in range(len(key)) if key[i] != slice(None, None)
#
# c:\Users\ge27fus\.conda\envs\fleetmaas\lib\site-packages\pandas\core\indexes\multi.py in get_loc(self, key, method)
#    2910         for i, k in enumerate(follow_key, len(lead_key)):
#    2911             mask = self.codes[i][loc] == self._get_loc_single_level_index(
# -> 2912                 self.levels[i], k
#    2913             )
#    2914             if not mask.all():
#
# c:\Users\ge27fus\.conda\envs\fleetmaas\lib\site-packages\pandas\core\indexes\multi.py in _get_loc_single_level_index(self, level_index, key)
#    2805             return -1
#    2806         else:
# -> 2807             return level_index.get_loc(key)
#    2808
#    2809     def get_loc(self, key, method=None):
#
# c:\Users\ge27fus\.conda\envs\fleetmaas\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: '0'

# %%
aggr_sup
# aggr_dem.xs(('5',cmpt_types[0],0)).requests_sh_1.plot()
# aggr_dem.xs(('20',cmpt_types[0],0)).requests_sh_1.plot()
# aggr_dem.xs(('50',cmpt_types[0],0)).requests_sh_1.plot()
# aggr_sup.xs(('5',cmpt_types[0],0)).ptcp_sh_0.plot()
# aggr_sup.xs(('20',cmpt_types[0],0)).ptcp_sh_0.plot()
# aggr_sup.xs(('50',cmpt_types[0],0)).ptcp_sh_0.plot()
aggr_sup.xs(('5',cmpt_types[0],0)).ptcp_sh_1.plot(label ='5')
aggr_sup.xs(('20',cmpt_types[0],0)).ptcp_sh_1.plot(label = '20')
aggr_sup.xs(('50',cmpt_types[0],0)).ptcp_sh_1.plot(label = '50')
plt.legend()
plt.show()
# Out:
# c:\Users\ge27fus\.conda\envs\fleetmaas\lib\site-packages\IPython\core\interactiveshell.py:2940: PerformanceWarning: indexing past lexsort depth may impact performance.
#   return runner(coro)
# c:\Users\ge27fus\.conda\envs\fleetmaas\lib\site-packages\IPython\core\interactiveshell.py:2940: PerformanceWarning: indexing past lexsort depth may impact performance.
#   return runner(coro)

# %%
conv_steady_days = 25
moving_average_days = 125
eql_dem = aggr_dem.groupby(['label'], sort=False).tail(conv_steady_days + moving_average_days).groupby(['label'],sort=False).mean()
eql_sup = aggr_sup.groupby(['label'], sort=False).tail(conv_steady_days + moving_average_days).groupby(['label'],sort=False).mean()

# %%
eql_dem
aggr_dem
# Out:
#                               informed_mh  informed_sh  registered_mh  \
# cost_comp cmpt_type repl day
# 5         ss        0    0            NaN         8255            NaN
#                          1            NaN        10203            NaN
#                          2            NaN        12085            NaN
#                          3            NaN        13973            NaN
#                          4            NaN        15657            NaN
# ...                                   ...          ...            ...
# 50        ss        0    280          NaN        30924            NaN
#                          281          NaN        30924            NaN
#                          282          NaN        30924            NaN
#                          283          NaN        30924            NaN
#                          284          NaN        30924            NaN
#
#                               registered_sh_0  registered_sh_1  requests_mh  \
# cost_comp cmpt_type repl day
# 5         ss        0    0               3163             3248          NaN
#                          1               3374             3610          NaN
#                          2               4063             3724          NaN
#                          3               4039             4659          NaN
#                          4               4977             4740          NaN
# ...                                       ...              ...          ...
# 50        ss        0    280                4            30920          NaN
#                          281                4            30920          NaN
#                          282                5            30919          NaN
#                          283                5            30919          NaN
#                          284                5            30919          NaN
#
#                               requests_sh_0  requests_sh_1  \
# cost_comp cmpt_type repl day
# 5         ss        0    0             1100           1130
#                          1             1066           1158
#                          2             1048           1174
#                          3             1254           1185
#                          4             1122           1389
# ...                                     ...            ...
# 50        ss        0    280              0           8856
#                          281              0           8902
#                          282              1           8908
#                          283              0           8973
#                          284              1           8772
#
#                               requests_sh_largest  gets_offer_mh_0  ...  \
# cost_comp cmpt_type repl day                                        ...
# 5         ss        0    0                   1130              NaN  ...
#                          1                   1158              NaN  ...
#                          2                   1174              NaN  ...
#                          3                   1254              NaN  ...
#                          4                   1389              NaN  ...
# ...                                           ...              ...  ...
# 50        ss        0    280                 8856              NaN  ...
#                          281                 8902              NaN  ...
#                          282                 8908              NaN  ...
#                          283                 8973              NaN  ...
#                          284                 8772              NaN  ...
#
#                               perc_wait_sh_smallest  perc_detour_mh  \
# cost_comp cmpt_type repl day
# 5         ss        0    0                55.523834             NaN
#                          1                92.373725             NaN
#                          2               110.712265             NaN
#                          3               129.255448             NaN
#                          4               159.239523             NaN
# ...                                             ...             ...
# 50        ss        0    280            1757.501435             NaN
#                          281            1757.501435             NaN
#                          282            1758.976202             NaN
#                          283            1758.976202             NaN
#                          284            1761.886957             NaN
#
#                               perc_detour_sh_0  perc_detour_sh_1  \
# cost_comp cmpt_type repl day
# 5         ss        0    0        5.629994e-08     -8.874640e-08
#                          1        1.085332e-07     -1.018255e-07
#                          2        1.312893e-07     -8.762936e-08
#                          3        1.229028e-07     -9.547431e-08
#                          4        1.424064e-07     -7.949294e-08
# ...                                        ...               ...
# 50        ss        0    280     -1.514396e-08      3.192149e-07
#                          281     -1.514396e-08      3.174915e-07
#                          282     -1.514396e-08      3.019186e-07
#                          283     -1.514396e-08      3.254975e-07
#                          284     -1.514396e-08      3.189800e-07
#
#                               perc_km_fare_mh  perc_km_fare_sh_0  \
# cost_comp cmpt_type repl day
# 5         ss        0    0                NaN                1.5
#                          1                NaN                1.5
#                          2                NaN                1.5
#                          3                NaN                1.5
#                          4                NaN                1.5
# ...                                       ...                ...
# 50        ss        0    280              NaN                1.5
#                          281              NaN                1.5
#                          282              NaN                1.5
#                          283              NaN                1.5
#                          284              NaN                1.5
#
#                               perc_km_fare_sh_1  label  service_rate_sh_0  \
# cost_comp cmpt_type repl day
# 5         ss        0    0                  1.5    NaN           0.997273
#                          1                  1.5    NaN           0.995310
#                          2                  1.5    NaN           1.000000
#                          3                  1.5    NaN           0.981659
#                          4                  1.5    NaN           1.000000
# ...                                         ...    ...                ...
# 50        ss        0    280                1.5    NaN                NaN
#                          281                1.5    NaN                NaN
#                          282                1.5    NaN           0.000000
#                          283                1.5    NaN                NaN
#                          284                1.5    NaN           0.000000
#
#                               service_rate_sh_1
# cost_comp cmpt_type repl day
# 5         ss        0    0             0.998230
#                          1             0.999136
#                          2             0.999148
#                          3             0.999156
#                          4             0.995680
# ...                                         ...
# 50        ss        0    280           0.999887
#                          281           0.999775
#                          282           0.999439
#                          283           1.000000
#                          284           0.999886
#
# [1876 rows x 47 columns]

# %%
# Create subplots within a single figure
n_rows = 2
n_cols = 4
fig, axes = plt.subplots(n_rows, n_cols, figsize=(16, 10))

indicators = ['registered_sh', 'requests_sh','service_rate_sh', 'exp_wait_sh', 'exp_detour_sh', 'registered_sh', 'ptcp_sh', 'exp_inc_sh']
stacked = [True, True, False, False, False, True, True, False]
type = ['dem', 'dem', 'dem', 'dem', 'dem', 'sup', 'sup', 'sup']

i = 0
for j, indicator in enumerate(indicators):
    
    k = j - i*n_cols
        # ax.bar(height=eql_dem[indicators[j]], x=eql_dem.index.values)
    
    if type[j] == 'dem':
        if stacked[j]:
            eql_dem[['{}_0'.format(indicators[j]),'{}_1'.format(indicators[j])]].plot(kind='bar', stacked=True, ax = axes[i, k], width=0.8)
        else:
            eql_dem[['{}_0'.format(indicators[j]),'{}_1'.format(indicators[j])]].plot(kind='bar', stacked=False, ax = axes[i, k], width = 0.8)
    else:
        if stacked[j]:
            eql_sup[['{}_0'.format(indicators[j]),'{}_1'.format(indicators[j])]].plot(kind='bar', stacked=True, ax = axes[i, k], width=0.8)
        else:
            eql_sup[['{}_0'.format(indicators[j]),'{}_1'.format(indicators[j])]].plot(kind='bar', stacked=False, ax = axes[i, k], width = 0.8)
    
    ax.set_xlabel('Day')
    ax.set_ylabel(indicators[j])
    ax.set_title(f'Column: {indicators[j]}')
    ax.legend()

    if j == n_cols-1:
        i+=1


# axes[0,0].set_ylim(0,35000)
# axes[0,1].set_ylim(0,10000)

plt.tight_layout()
plt.savefig('Eql-dem-indicators.png', facecolor='w')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-b24877125149> in <module>
#      16     if type[j] == 'dem':
#      17         if stacked[j]:
# ---> 18             eql_dem[['{}_0'.format(indicators[j]),'{}_1'.format(indicators[j])]].plot(kind='bar', stacked=True, ax = axes[i, k], width=0.8)
#      19         else:
#      20             eql_dem[['{}_0'.format(indicators[j]),'{}_1'.format(indicators[j])]].plot(kind='bar', stacked=False, ax = axes[i, k], width = 0.8)
#
# c:\Users\ge27fus\.conda\envs\fleetmaas\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# --> 955         return plot_backend.plot(data, kind=kind, **kwargs)
#     956
#     957     __call__.__doc__ = __doc__
#
# c:\Users\ge27fus\.conda\envs\fleetmaas\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# c:\Users\ge27fus\.conda\envs\fleetmaas\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     285         for ax in self.axes:
#     286             self._post_plot_logic_common(ax, self.data)
# --> 287             self._post_plot_logic(ax, self.data)
#     288
#     289     def _args_adjust(self):
#
# c:\Users\ge27fus\.conda\envs\fleetmaas\lib\site-packages\pandas\plotting\_matplotlib\core.py in _post_plot_logic(self, ax, data)
#    1512         e_edge = self.ax_pos.max() + 0.25 + self.bar_width + self.lim_offset
#    1513
# -> 1514         self._decorate_ticks(ax, name, str_index, s_edge, e_edge)
#    1515
#    1516     def _decorate_ticks(self, ax: "Axes", name, ticklabels, start_edge, end_edge):
#
# c:\Users\ge27fus\.conda\envs\fleetmaas\lib\site-packages\pandas\plotting\_matplotlib\core.py in _decorate_ticks(self, ax, name, ticklabels, start_edge, end_edge)
#    1515
#    1516     def _decorate_ticks(self, ax: "Axes", name, ticklabels, start_edge, end_edge):
# -> 1517         ax.set_xlim((start_edge, end_edge))
#    1518
#    1519         if self.xticks is not None:
#
# c:\Users\ge27fus\.conda\envs\fleetmaas\lib\site-packages\matplotlib\axes\_base.py in set_xlim(self, left, right, emit, auto, xmin, xmax)
#    3695
#    3696         self._process_unit_info([("x", (left, right))], convert=False)
# -> 3697         left = self._validate_converted_limits(left, self.convert_xunits)
#    3698         right = self._validate_converted_limits(right, self.convert_xunits)
#    3699
#
# c:\Users\ge27fus\.conda\envs\fleetmaas\lib\site-packages\matplotlib\axes\_base.py in _validate_converted_limits(self, limit, convert)
#    3612             if (isinstance(converted_limit, Real)
#    3613                     and not np.isfinite(converted_limit)):
# -> 3614                 raise ValueError("Axis limits cannot be NaN or Inf")
#    3615             return converted_limit
#    3616
#
# ValueError: Axis limits cannot be NaN or Inf

# %%
aggr_sup.xs(('0', cmpt_types[0], 1), level=[var_name, 'cmpt_type', 'repl']).ptcp_sh_0.rolling(25).mean().rolling(100).mean().diff().abs().plot()
aggr_sup.xs(('0', cmpt_types[0], 1), level=[var_name, 'cmpt_type', 'repl']).ptcp_sh_1.rolling(25).mean().rolling(100).mean().diff().abs().plot()
# aggr_sup.xs(('sp', 3), level=['cmpt_type', 'repl']).ptcp_0.rolling(25).mean().rolling(50).mean().diff().abs().plot()
plt.axhline(y=0.05)
# plt.axhline(y=0.1)
plt.ylim(0,0.5)
plt.xlim(0,415)

# aggr_sup.xs(('sp', 4), level=['cmpt_type', 'repl']).ptcp_sh_1.rolling(25).mean().rolling(50).mean().tail(10).diff().abs() < 10
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\ge27fus\.conda\envs\fleetmaas\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '0'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-b8d827e88baf> in <module>
# ----> 1 aggr_sup.xs(('0', cmpt_types[0], 1), level=[var_name, 'cmpt_type', 'repl']).ptcp_sh_0.rolling(25).mean().rolling(100).mean().diff().abs().plot()
#       2 aggr_sup.xs(('0', cmpt_types[0], 1), level=[var_name, 'cmpt_type', 'repl']).ptcp_sh_1.rolling(25).mean().rolling(100).mean().diff().abs().plot()
#       3 # aggr_sup.xs(('sp', 3), level=['cmpt_type', 'repl']).ptcp_0.rolling(25).mean().rolling(50).mean().diff().abs().plot()
#       4 plt.axhline(y=0.05)
#       5 # plt.axhline(y=0.1)
#
# c:\Users\ge27fus\.conda\envs\fleetmaas\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3706             if not isinstance(labels, MultiIndex):
#    3707                 raise TypeError("Index must be a MultiIndex")
# -> 3708             loc, new_ax = labels.get_loc_level(key, level=level, drop_level=drop_level)
#    3709
#    3710             # create the tuple of the indexer
#
# c:\Users\ge27fus\.conda\envs\fleetmaas\lib\site-packages\pandas\core\indexes\multi.py in get_loc_level(self, key, level, drop_level)
#    2961         else:
#    2962             level = [self._get_level_number(lev) for lev in level]
# -> 2963         return self._get_loc_level(key, level=level, drop_level=drop_level)
#    2964
#    2965     def _get_loc_level(
#
# c:\Users\ge27fus\.conda\envs\fleetmaas\lib\site-packages\pandas\core\indexes\multi.py in _get_loc_level(self, key, level, drop_level)
#    2993             result = None
#    2994             for lev, k in zip(level, key):
# -> 2995                 loc, new_index = self._get_loc_level(k, level=lev)
#    2996                 if isinstance(loc, slice):
#    2997                     mask = np.zeros(len(self), dtype=bool)
#
# c:\Users\ge27fus\.conda\envs\fleetmaas\lib\site-packages\pandas\core\indexes\multi.py in _get_loc_level(self, key, level, drop_level)
#    3064                 return indexer, maybe_mi_droplevels(indexer, ilevels, drop_level)
#    3065         else:
# -> 3066             indexer = self._get_level_indexer(key, level=level)
#    3067             return indexer, maybe_mi_droplevels(indexer, [level], drop_level)
#    3068
#
# c:\Users\ge27fus\.conda\envs\fleetmaas\lib\site-packages\pandas\core\indexes\multi.py in _get_level_indexer(self, key, level, indexer)
#    3154         else:
#    3155
# -> 3156             idx = self._get_loc_single_level_index(level_index, key)
#    3157
#    3158             if level > 0 or self.lexsort_depth == 0:
#
# c:\Users\ge27fus\.conda\envs\fleetmaas\lib\site-packages\pandas\core\indexes\multi.py in _get_loc_single_level_index(self, level_index, key)
#    2805             return -1
#    2806         else:
# -> 2807             return level_index.get_loc(key)
#    2808
#    2809     def get_loc(self, key, method=None):
#
# c:\Users\ge27fus\.conda\envs\fleetmaas\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: '0'

# %%
aggr_sup.xs(('3', cmpt_types[0], 1), level=[var_name, 'cmpt_type', 'repl']).ptcp_sh_0.plot()
aggr_sup.xs(('3', cmpt_types[0], 1), level=[var_name, 'cmpt_type', 'repl']).ptcp_sh_1.plot()
# Out:
# <AxesSubplot:xlabel='day'>

# %%
aggr_sup.xs(('0.1'), level='start_reg_plf_share').head(20)
# Out:
#                     informed_mh  informed_sh  registered_mh  registered_sh_0  \
# cmpt_type repl day
# sp        0    0            NaN          641            NaN               24
#                1            NaN          750            NaN               23
#                2            NaN          837            NaN               20
#                3            NaN          906            NaN               19
#                4            NaN          971            NaN               19
#                5            NaN         1033            NaN               17
#                6            NaN         1088            NaN               15
#                7            NaN         1154            NaN               13
#                8            NaN         1228            NaN               11
#                9            NaN         1291            NaN                9
#                10           NaN         1349            NaN                9
#                11           NaN         1419            NaN                8
#                12           NaN         1481            NaN                6
#                13           NaN         1539            NaN                6
#                14           NaN         1595            NaN                5
#                15           NaN         1649            NaN                3
#                16           NaN         1708            NaN                3
#                17           NaN         1756            NaN                3
#                18           NaN         1807            NaN                3
#                19           NaN         1855            NaN                2
#
#                     registered_sh_1  ptcp_mh  ptcp_sh_0  ptcp_sh_1  \
# cmpt_type repl day
# sp        0    0                207      NaN         14        141
#                1                195      NaN         14        119
#                2                193      NaN         11         97
#                3                194      NaN          9         93
#                4                189      NaN          8         90
#                5                189      NaN          6         97
#                6                187      NaN          5        101
#                7                192      NaN          4        107
#                8                198      NaN          2        113
#                9                211      NaN          2        124
#                10               221      NaN          1        134
#                11               222      NaN          1        142
#                12               234      NaN          1        146
#                13               229      NaN          0        159
#                14               228      NaN          0        156
#                15               226      NaN          0        157
#                16               226      NaN          0        158
#                17               224      NaN          0        159
#                18               223      NaN          0        158
#                19               218      NaN          0        157
#
#                     exp_inc_mh  exp_inc_sh_0  ...  perc_inc_mh  perc_inc_sh_0  \
# cmpt_type repl day                            ...
# sp        0    0           NaN     70.676071  ...          NaN      94.505834
#                1           NaN     61.809464  ...          NaN      78.623125
#                2           NaN     65.631364  ...          NaN      73.035214
#                3           NaN     72.561389  ...          NaN      72.942439
#                4           NaN     68.586562  ...          NaN      71.948510
#                5           NaN     73.953750  ...          NaN      72.318174
#                6           NaN     65.675500  ...          NaN      71.056445
#                7           NaN     75.494375  ...          NaN      71.747446
#                8           NaN     78.837500  ...          NaN      72.778237
#                9           NaN     55.846250  ...          NaN      70.472828
#                10          NaN     59.762500  ...          NaN      69.404287
#                11          NaN      3.060000  ...          NaN      61.420189
#                12          NaN     22.062500  ...          NaN      57.220780
#                13          NaN      0.000000  ...          NaN      57.220780
#                14          NaN      0.000000  ...          NaN      57.220780
#                15          NaN      0.000000  ...          NaN      57.220780
#                16          NaN      0.000000  ...          NaN      57.220780
#                17          NaN      0.000000  ...          NaN      57.220780
#                18          NaN      0.000000  ...          NaN      57.220780
#                19          NaN      0.000000  ...          NaN      57.220780
#
#                     perc_inc_sh_1  new_regist_sh_0  new_deregist_sh_0  \
# cmpt_type repl day
# sp        0    0       148.533552                0                  0
#                1       125.904994                0                  1
#                2       114.868219                0                  3
#                3       110.880386                0                  1
#                4       109.129118                0                  0
#                5       107.978478                0                  2
#                6       107.358614                0                  2
#                7       106.797331                0                  2
#                8       106.594344                0                  2
#                9       106.250326                0                  2
#                10      106.087509                0                  0
#                11      106.056391                0                  1
#                12      106.150098                0                  2
#                13      105.888190                0                  0
#                14      105.901738                0                  1
#                15      106.317527                0                  2
#                16      106.284901                0                  0
#                17      106.186660                0                  0
#                18      105.738612                0                  0
#                19      105.697784                0                  1
#
#                     new_regist_sh_1  new_deregist_sh_1  new_regist_mh  \
# cmpt_type repl day
# sp        0    0                  0                  0              0
#                1                  1                 13              0
#                2                 14                 16              0
#                3                 12                 11              0
#                4                 17                 22              0
#                5                 12                 12              0
#                6                 13                 15              0
#                7                 10                  5              0
#                8                 17                 11              0
#                9                 17                  4              0
#                10                13                  3              0
#                11                11                 10              0
#                12                15                  3              0
#                13                 1                  6              0
#                14                 2                  3              0
#                15                 3                  5              0
#                16                 3                  3              0
#                17                 1                  3              0
#                18                 3                  4              0
#                19                 0                  5              0
#
#                     new_deregist_mh  label
# cmpt_type repl day
# sp        0    0                  0    NaN
#                1                  0    NaN
#                2                  0    NaN
#                3                  0    NaN
#                4                  0    NaN
#                5                  0    NaN
#                6                  0    NaN
#                7                  0    NaN
#                8                  0    NaN
#                9                  0    NaN
#                10                 0    NaN
#                11                 0    NaN
#                12                 0    NaN
#                13                 0    NaN
#                14                 0    NaN
#                15                 0    NaN
#                16                 0    NaN
#                17                 0    NaN
#                18                 0    NaN
#                19                 0    NaN
#
# [20 rows x 21 columns]

# %%
aggr_dem.xs((cmpt_types[0], 4), level=['cmpt_type', 'repl']).requests_sh_0.rolling(25).mean().rolling(100).mean().diff().abs().plot()
aggr_dem.xs((cmpt_types[0], 4), level=['cmpt_type', 'repl']).requests_sh_1.rolling(25).mean().rolling(100).mean().diff().abs().plot()
# aggr_sup.xs(('sp', 3), level=['cmpt_type', 'repl']).ptcp_0.rolling(25).mean().rolling(50).mean().diff().abs().plot()
# plt.axhline(y=0)
plt.axhline(y=2)
plt.ylim(0,10)
# plt.xlim(0,415)
# Out:
# (0.0, 10.0)

# %%
# Create df with market (system) level indicators
aggr_dem_reset = aggr_dem.reset_index()
aggr_sup_reset = aggr_sup.reset_index()
market_df = aggr_dem_reset.reset_index().copy()[['day','label']]
market_df['tot_regist_dem'] = aggr_dem_reset.registered_mh + aggr_dem_reset.registered_sh_0 + aggr_dem_reset.registered_sh_1.fillna(0)
market_df['market_share'] = (aggr_dem_reset.accepts_offer_0 + aggr_dem_reset.accepts_offer_1.fillna(0)) / 100000
# market_df['exp_wait'] = aggr_dem_reset.corr_xp_wait
# market_df['exp_ivt'] = aggr_dem_reset.xp_ivt
market_df['tot_regist_sup'] = aggr_sup_reset.registered_mh + aggr_sup_reset.registered_sh_0 + aggr_sup_reset.registered_sh_1.fillna(0)
market_df['tot_ptcp'] = aggr_sup_reset.ptcp_mh + aggr_sup_reset.ptcp_sh_0 + aggr_sup_reset.ptcp_sh_1.fillna(0)
market_df['exp_inc'] = aggr_sup_reset.exp_inc
# market_df['perc_inc_reg_mh'] = aggr_sup_reset.perc_inc_reg_mh
# market_df['perc_inc_notreg_mh'] = aggr_sup_reset.perc_inc_notreg_mh
market_df['rel_pickup_dist'] = aggr_sup_reset.pickup_dist / market_df.market_share / 100000
market_df['rel_repos_dist'] = aggr_sup_reset.repos_dist / market_df.market_share / 100000
market_df['rel_serving_dist'] = (aggr_sup_reset.km_occ_1.fillna(0) + aggr_sup_reset.km_occ_2.fillna(0) + aggr_sup_reset.km_occ_3.fillna(0) + aggr_sup_reset.km_occ_4.fillna(0)) / market_df.market_share / 100000
market_df['driver_per_req'] = market_df.tot_ptcp / market_df.market_share / 100000
market_df['service_rate'] = (aggr_dem_reset.accepts_offer_0 + aggr_dem_reset.accepts_offer_1.fillna(0)) / (aggr_dem_reset.requests_mh + aggr_dem_reset.requests_sh_0 + aggr_dem_reset.requests_sh_1.fillna(0))
market_df['service_rate_0'] = aggr_dem_reset.gets_offer_0 / aggr_dem_reset.requests_0
market_df['service_rate_1'] = aggr_dem_reset.gets_offer_1 / aggr_dem_reset.requests_1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-298244a47a31> in <module>
#       4 market_df = aggr_dem_reset.reset_index().copy()[['day','label']]
#       5 market_df['tot_regist_dem'] = aggr_dem_reset.registered_mh + aggr_dem_reset.registered_sh_0 + aggr_dem_reset.registered_sh_1.fillna(0)
# ----> 6 market_df['market_share'] = (aggr_dem_reset.accepts_offer_0 + aggr_dem_reset.accepts_offer_1.fillna(0)) / 100000
#       7 # market_df['exp_wait'] = aggr_dem_reset.corr_xp_wait
#       8 # market_df['exp_ivt'] = aggr_dem_reset.xp_ivt
#
# c:\Users\ge27fus\.conda\envs\fleetmaas\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5458             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5459                 return self[name]
# -> 5460             return object.__getattribute__(self, name)
#    5461
#    5462     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'accepts_offer_0'

# %%
# plot data in stack manner of bar type
eql_dem['rs'] = eql_dem.accepts_offer_0 + eql_dem.accepts_offer_1.fillna(0)

# Create the stacked bar chart
ax = (eql_dem[['rs','bike','car','pt']] / 100000 * 100).reset_index().plot(x='label', kind='bar', stacked=True,
        title='Modal share under different ridesourcing service types')

# # Label bars with their values
# for container in ax.containers:
#     ax.bar_label(container, label_type='center', fontsize=10, padding=3, labels=[f'{h:.2f}' for h in container.get_heights()])

# Label bars with their values
for container in ax.containers:
    ax.bar_label(container, label_type='center', fontsize=10, padding=3, fmt='%.1f%%')
# Show the plot
plt.ylabel('Modal share (%)')
plt.legend(bbox_to_anchor=(1, 0.5))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-ea9e376c3bb8> in <module>
#       1 # plot data in stack manner of bar type
# ----> 2 eql_dem['rs'] = eql_dem.accepts_offer_0 + eql_dem.accepts_offer_1.fillna(0)
#       3
#       4 # Create the stacked bar chart
#       5 ax = (eql_dem[['rs','bike','car','pt']] / 100000 * 100).reset_index().plot(x='label', kind='bar', stacked=True,
#
# NameError: name 'eql_dem' is not defined

# %%
eql_dem.keys()
# Out:
# Index(['informed', 'registered_0', 'requests_0', 'gets_offer_0',
#        'accepts_offer_0', 'bike', 'car', 'pt', 'time_occ_1',
#        'init_perc_wait_0', 'xp_wait_0', 'corr_xp_wait_0', 'init_perc_ivt_0',
#        'xp_ivt_0', 'init_perc_km_fare_0', 'xp_km_fare_0', 'informed_mh',
#        'informed_sh', 'registered_mh', 'registered_sh_0', 'registered_sh_1',
#        'requests_mh', 'requests_sh_0', 'requests_sh_1', 'gets_offer_mh_0',
#        'gets_offer_mh_1', 'gets_offer_sh_0', 'gets_offer_sh_1',
#        'accepts_offer_mh_0', 'accepts_offer_mh_1', 'exp_wait_mh',
#        'exp_wait_sh_0', 'exp_wait_sh_1', 'exp_corr_wait_mh',
#        'exp_corr_wait_sh_0', 'exp_corr_wait_sh_1', 'exp_ivt_mh',
#        'exp_ivt_sh_0', 'exp_ivt_sh_1', 'exp_km_fare_mh', 'exp_km_fare_sh_0',
#        'exp_km_fare_sh_1', 'perc_wait_mh', 'perc_wait_sh_0', 'perc_wait_sh_1',
#        'perc_ivt_mh', 'perc_ivt_sh_0', 'perc_ivt_sh_1', 'perc_km_fare_mh',
#        'perc_km_fare_sh_0', 'perc_km_fare_sh_1', 'eff_pax_dist_0',
#        'eff_pax_dist_1', 'time_occ_2', 'time_occ_3', 'time_occ_4',
#        'time_occ_5', 'time_occ_6', 'registered_1', 'requests_1',
#        'gets_offer_1', 'accepts_offer_1', 'init_perc_wait_1', 'xp_wait_1',
#        'corr_xp_wait_1', 'init_perc_ivt_1', 'xp_ivt_1', 'init_perc_km_fare_1',
#        'xp_km_fare_1', 'rs', 'former_bike', 'former_car', 'former_pt'],
#       dtype='object')

# %%
mode_df
# Out:
#        no_rs_bike  no_rs_car  no_rs_pt  other_trav_bike  other_trav_car  \
# label
# s         15254.2    10212.2    6016.4          57613.8          8337.6
# p         15254.2    10212.2    6016.4          57613.8          8337.6
# ss        15254.2    10212.2    6016.4          57613.8          8337.6
# pp        15254.2    10212.2    6016.4          57613.8          8337.6
# sp        15254.2    10212.2    6016.4          57613.8          8337.6
#
#        other_trav_pt
# label
# s             2565.8
# p             2565.8
# ss            2565.8
# pp            2565.8
# sp            2565.8

# %%
# Create the stacked bar chart
ax = (eql_dem[['former_bike','former_car','former_pt']]).div((eql_dem['requests_0'] + eql_dem['requests_1'].fillna(0)) / 100, axis=0).reset_index().plot(x='label', kind='bar', stacked=True,
        title='Modal share under different ridesourcing service types')

# # Label bars with their values
# for container in ax.containers:
#     ax.bar_label(container, label_type='center', fontsize=10, padding=3, labels=[f'{h:.2f}' for h in container.get_heights()])

# Label bars with their values
for container in ax.containers:
    ax.bar_label(container, label_type='center', fontsize=10, padding=3, fmt='%.1f%%')
# Show the plot
plt.ylabel('Modal share (%)')
plt.legend(bbox_to_anchor=(1, 0.5))
plt.show()

# waarom 50 procent bij requests_sh_0, requests_sh_1 en requests_mh, gaat iets fout? heeft iets met singlehoming en multihoming te maken? bars zijn ook niet helemaal gelijk?
# dit plaatje met accepts_offer kan meer zijn dan 1 omdat er ook requests worden afggewezen?
# Note: requests is niet goed als er multi-homers zijn. Bars zijn ook niet allemaal gelijk?

# %%
eql_sup.perc_inc_sh_1
# Out:
# label
# p            NaN
# pp     90.855327
# s            NaN
# sp     92.517338
# ss    103.892037
# Name: perc_inc_sh_1, dtype: float64

# %%
eql_dem.former_bike + eql_dem.former_car + eql_dem.former_pt
# Out:
# label
# p     7689.365000
# pp    8253.585000
# s     8274.950000
# sp    8585.223333
# ss    8475.010000
# dtype: float64

# %%
eql_dem.eff_pax_dist_0 / 1000
# Out:
# label
# p     47533.505327
# pp    25584.902239
# s     51745.611390
# sp    34966.154447
# ss    26476.082616
# Name: eff_pax_dist_0, dtype: float64

# %%
# Create the stacked bar chart
ax = (eql_sup[['km_occ_1','km_occ_2','km_occ_3','km_occ_4','pickup_dist','repos_dist']]).div((eql_dem['eff_pax_dist_0'] + eql_dem['eff_pax_dist_1'].fillna(0)) / 1000, axis=0).reset_index().plot(x='label', kind='bar', stacked=True,
        title='Veh km per pax km')

# # Label bars with their values
# for container in ax.containers:
#     ax.bar_label(container, label_type='center', fontsize=10, padding=3, labels=[f'{h:.2f}' for h in container.get_heights()])

# Label bars with their values
# for container in ax.containers:
#     ax.bar_label(container, label_type='center', fontsize=10, padding=3, fmt='%.2f')
# Show the plot
plt.ylabel('Veh km per pax km')
plt.legend(bbox_to_anchor=(1, 0.5))
plt.show()

# %%
aggr_sup.xs('s',level=0,axis=0).exp_inc_sh_0.tail(20)
# Out:
# day
# 185    109.040644
# 186    109.076793
# 187    109.409295
# 188    107.938524
# 189    107.399305
# 190    107.638087
# 191    108.258073
# 192    107.999924
# 193    108.714377
# 194    107.990775
# 195    108.874167
# 196    108.769705
# 197    108.490569
# 198    108.642437
# 199    107.078370
# 200    107.857525
# 201    106.723025
# 202    108.418285
# 203    109.111213
# 204    107.587786
# Name: exp_inc_sh_0, dtype: float64

# %%
aggr_sup.xs('s',level=0,axis=0).perc_inc_sh_0.tail(20)
# Out:
# day
# 185    107.807821
# 186    107.899680
# 187    108.019020
# 188    108.124763
# 189    108.088479
# 190    107.972919
# 191    107.988397
# 192    107.932681
# 193    107.894790
# 194    107.999644
# 195    107.969617
# 196    107.987790
# 197    108.021464
# 198    108.010366
# 199    108.038841
# 200    107.847840
# 201    107.715811
# 202    107.221594
# 203    107.874413
# 204    108.563100
# Name: perc_inc_sh_0, dtype: float64

# %%
aggr_sup.xs('sp',level=0,axis=0).perc_inc_sh_1.plot()
aggr_sup.xs('sp',level=0,axis=0).exp_inc_sh_1.plot()
# Out:
# <AxesSubplot:xlabel='day'>
